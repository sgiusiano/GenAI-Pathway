# %%
import sys
sys.path.append('..')

from src.graph.graph import create_graph_with_checkpoints

# %% [markdown]
# # CX Support LangGraph System - Demo Notebook
#
# This notebook demonstrates:
# - ✅ **Graph Visualization** - Complete workflow structure
# - ✅ **Supervisor Routing** - To Sales and Post-Sales specialists
# - ✅ **Dynamic Tool Binding** - Retrieve → Rank → Bind top-3 tools
# - ✅ **Streaming Execution** - Step-by-step workflow visibility
# - ✅ **Checkpointing** - State management with MemorySaver

# %% [markdown]
# ## Graph Visualization
#
# Let's visualize the complete graph structure:

# %%
# Create and visualize the graph
graph = create_graph_with_checkpoints()

print("="*80)
print("GRAPH STRUCTURE")
print("="*80)
print()

# Try to display Mermaid visualization
try:
    from IPython.display import Image, display
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception as e:
    print(f"Note: Mermaid visualization not available ({e})")
    print("\nFalling back to ASCII representation:")
    print(graph.get_graph().draw_ascii())
# Out:
# ...
# GRAPH STRUCTURE
# ...

# %% [markdown]
# ## Run Complete Demo
#
# Now let's run the complete demo with streaming execution:

# %%
# Import and run the complete demo
from main import run_complete_demo

run_complete_demo()
# Out:
# 🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬
#   CX SUPPORT LANGGRAPH SYSTEM - DEMONSTRATION
# 🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬🎬
#
# ...
#   PART 1: Sales Flow with Streaming - Product Inquiry
# ...
#
# 📝 Customer Request: 'I'd like to schedule a demo for the Premium Business Laptop'
#
# 🔄 Streaming execution steps:
#
# ──────────────────────────────────────────────────────────────────────
# Step 1: Node 'supervisor' executed
# ──────────────────────────────────────────────────────────────────────
#   → Routing decision: sales
#   → Current stage: sales
#   → Message added [AIMessage]: [Supervisor] Routing your request to the Sales Specialist to assist you with scheduling a demo for t...
#   → Scratch updated: ['specialist_task']
#
#
# [Sales Agent] Tool Scores:
#   ✓ schedule_demo: 0.484
#   ✓ get_competitor_comparison: 0.236
#   ✓ calculate_discount: 0.235
#     check_customer_eligibility: 0.204
#     get_pricing: 0.203
#     check_inventory: 0.154
#     search_product_catalog: 0.150
# ...
